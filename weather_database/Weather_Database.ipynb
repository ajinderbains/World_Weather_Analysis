# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Import the random module.
import random
# Import the NumPy module.
import numpy as np
# Import timeit.
import timeit
import pandas as pd
import matplotlib.pyplot as plt
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
   
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
    # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
    # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather['weather'][0]['description']
    # Convert the date to ISO standard.
        
    # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
        
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Convert the array of dictionaries to a Pandas DataFrame.
#city_data_df = pd.DataFrame(city_data)
#city_data_df
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | abu dhabi
# Processing Record 2 of Set 1 | lerici
# Processing Record 3 of Set 1 | castro
# Processing Record 4 of Set 1 | woodward
# Processing Record 5 of Set 1 | tuy hoa
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | cayenne
# Processing Record 9 of Set 1 | provideniya
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | bacuit
# City not found. Skipping...
# Processing Record 13 of Set 1 | san andres
# Processing Record 14 of Set 1 | thunder bay
# Processing Record 15 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 1 | vardo
# Processing Record 17 of Set 1 | sao filipe
# Processing Record 18 of Set 1 | nouadhibou
# Processing Record 19 of Set 1 | ekibastuz
# Processing Record 20 of Set 1 | port elizabeth
# Processing Record 21 of Set 1 | ponta do sol
# Processing Record 22 of Set 1 | tiarei
# Processing Record 23 of Set 1 | srednekolymsk
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | shieli
# Processing Record 26 of Set 1 | bambanglipuro
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | bambous virieux
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | pisco
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | sao joao da barra
# Processing Record 35 of Set 1 | port alberni
# Processing Record 36 of Set 1 | finschhafen
# Processing Record 37 of Set 1 | saint-philippe
# Processing Record 38 of Set 1 | carnarvon
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | bengkulu
# Processing Record 41 of Set 1 | yellapur
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | rikitea
# Processing Record 44 of Set 1 | erenhot
# Processing Record 45 of Set 1 | yulara
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | ust-ilimsk
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | kodiak
# Processing Record 1 of Set 2 | upernavik
# Processing Record 2 of Set 2 | klaksvik
# Processing Record 3 of Set 2 | ziway
# Processing Record 4 of Set 2 | mumford
# Processing Record 5 of Set 2 | atuona
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | tocopilla
# Processing Record 8 of Set 2 | sabha
# Processing Record 9 of Set 2 | iqaluit
# Processing Record 10 of Set 2 | waddan
# Processing Record 11 of Set 2 | komsomolskiy
# Processing Record 12 of Set 2 | carballo
# Processing Record 13 of Set 2 | faanui
# Processing Record 14 of Set 2 | fairbanks
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | hasaki
# Processing Record 17 of Set 2 | bluff
# Processing Record 18 of Set 2 | busselton
# Processing Record 19 of Set 2 | mount isa
# Processing Record 20 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 2 | nikolskoye
# Processing Record 22 of Set 2 | shelburne
# Processing Record 23 of Set 2 | half moon bay
# Processing Record 24 of Set 2 | kapaa
# Processing Record 25 of Set 2 | kadykchan
# City not found. Skipping...
# Processing Record 26 of Set 2 | kokopo
# Processing Record 27 of Set 2 | vitim
# Processing Record 28 of Set 2 | thompson
# Processing Record 29 of Set 2 | kavieng
# Processing Record 30 of Set 2 | mahebourg
# Processing Record 31 of Set 2 | pacific grove
# Processing Record 32 of Set 2 | santiago del estero
# Processing Record 33 of Set 2 | santa cruz de la palma
# Processing Record 34 of Set 2 | bubaque
# Processing Record 35 of Set 2 | yetkul
# Processing Record 36 of Set 2 | labuhan
# Processing Record 37 of Set 2 | taksimo
# Processing Record 38 of Set 2 | sao jose da coroa grande
# Processing Record 39 of Set 2 | hobyo
# Processing Record 40 of Set 2 | mataura
# Processing Record 41 of Set 2 | lorengau
# Processing Record 42 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 2 | olafsvik
# Processing Record 44 of Set 2 | salinas
# Processing Record 45 of Set 2 | barrow
# Processing Record 46 of Set 2 | taoudenni
# Processing Record 47 of Set 2 | cockburn town
# Processing Record 48 of Set 2 | nyimba
# Processing Record 49 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 3 | saint george
# Processing Record 2 of Set 3 | acapulco
# Processing Record 3 of Set 3 | urumqi
# Processing Record 4 of Set 3 | nanortalik
# Processing Record 5 of Set 3 | mao
# Processing Record 6 of Set 3 | marystown
# Processing Record 7 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 3 | oktyabrskiy
# Processing Record 9 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 3 | maine-soroa
# Processing Record 11 of Set 3 | ancud
# Processing Record 12 of Set 3 | norman wells
# Processing Record 13 of Set 3 | ribeira grande
# Processing Record 14 of Set 3 | guerrero negro
# Processing Record 15 of Set 3 | katsuura
# Processing Record 16 of Set 3 | kaitangata
# Processing Record 17 of Set 3 | ikom
# Processing Record 18 of Set 3 | tunduru
# City not found. Skipping...
# Processing Record 19 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 3 | severo-kurilsk
# Processing Record 21 of Set 3 | lucapa
# Processing Record 22 of Set 3 | lebu
# Processing Record 23 of Set 3 | tuktoyaktuk
# Processing Record 24 of Set 3 | dorobantu
# Processing Record 25 of Set 3 | tasiilaq
# Processing Record 26 of Set 3 | cabo san lucas
# Processing Record 27 of Set 3 | codrington
# Processing Record 28 of Set 3 | filingue
# Processing Record 29 of Set 3 | luderitz
# Processing Record 30 of Set 3 | cherskiy
# Processing Record 31 of Set 3 | axixa do tocantins
# City not found. Skipping...
# Processing Record 32 of Set 3 | whitley bay
# Processing Record 33 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 3 | atlantis
# Processing Record 35 of Set 3 | oistins
# Processing Record 36 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 3 | torbay
# Processing Record 38 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 3 | chiriqui
# Processing Record 40 of Set 3 | yahualica
# Processing Record 41 of Set 3 | saint-georges
# Processing Record 42 of Set 3 | namtsy
# Processing Record 43 of Set 3 | murdochville
# Processing Record 44 of Set 3 | bethel
# Processing Record 45 of Set 3 | khatanga
# Processing Record 46 of Set 3 | seymchan
# Processing Record 47 of Set 3 | bilibino
# Processing Record 48 of Set 3 | ko samui
# Processing Record 49 of Set 3 | chumikan
# Processing Record 50 of Set 3 | faya
# Processing Record 1 of Set 4 | east london
# Processing Record 2 of Set 4 | birjand
# Processing Record 3 of Set 4 | umm lajj
# Processing Record 4 of Set 4 | najran
# Processing Record 5 of Set 4 | paso de carrasco
# Processing Record 6 of Set 4 | sioux lookout
# Processing Record 7 of Set 4 | luau
# Processing Record 8 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 4 | siderno
# Processing Record 10 of Set 4 | waipawa
# Processing Record 11 of Set 4 | sidi ali
# Processing Record 12 of Set 4 | namatanai
# Processing Record 13 of Set 4 | tartki
# City not found. Skipping...
# Processing Record 14 of Set 4 | ossora
# Processing Record 15 of Set 4 | port alfred
# Processing Record 16 of Set 4 | chuy
# Processing Record 17 of Set 4 | ust-maya
# Processing Record 18 of Set 4 | qaanaaq
# Processing Record 19 of Set 4 | souillac
# Processing Record 20 of Set 4 | ventspils
# Processing Record 21 of Set 4 | gelemso
# Processing Record 22 of Set 4 | hovd
# Processing Record 23 of Set 4 | touros
# Processing Record 24 of Set 4 | talara
# Processing Record 25 of Set 4 | saint-augustin
# Processing Record 26 of Set 4 | lavras da mangabeira
# Processing Record 27 of Set 4 | jabiru
# City not found. Skipping...
# Processing Record 28 of Set 4 | kruisfontein
# Processing Record 29 of Set 4 | kamenka
# Processing Record 30 of Set 4 | villanueva
# Processing Record 31 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 4 | atar
# Processing Record 33 of Set 4 | chokurdakh
# Processing Record 34 of Set 4 | bama
# Processing Record 35 of Set 4 | huarmey
# Processing Record 36 of Set 4 | cidreira
# Processing Record 37 of Set 4 | wahpeton
# Processing Record 38 of Set 4 | teknaf
# Processing Record 39 of Set 4 | ketchikan
# Processing Record 40 of Set 4 | timizart
# Processing Record 41 of Set 4 | praya
# Processing Record 42 of Set 4 | whitehorse
# Processing Record 43 of Set 4 | marv dasht
# City not found. Skipping...
# Processing Record 44 of Set 4 | ilulissat
# Processing Record 45 of Set 4 | shimoda
# Processing Record 46 of Set 4 | amahai
# Processing Record 47 of Set 4 | abnub
# Processing Record 48 of Set 4 | buala
# Processing Record 49 of Set 4 | garden city
# Processing Record 50 of Set 4 | dikson
# Processing Record 1 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 5 | den helder
# Processing Record 3 of Set 5 | hamilton
# Processing Record 4 of Set 5 | the valley
# Processing Record 5 of Set 5 | cradock
# Processing Record 6 of Set 5 | karratha
# Processing Record 7 of Set 5 | samarai
# Processing Record 8 of Set 5 | monki
# Processing Record 9 of Set 5 | nador
# Processing Record 10 of Set 5 | zaysan
# Processing Record 11 of Set 5 | mahanoro
# Processing Record 12 of Set 5 | kerema
# Processing Record 13 of Set 5 | porto velho
# Processing Record 14 of Set 5 | prince albert
# Processing Record 15 of Set 5 | guatire
# Processing Record 16 of Set 5 | sitka
# Processing Record 17 of Set 5 | hit
# Processing Record 18 of Set 5 | constitucion
# Processing Record 19 of Set 5 | dunedin
# Processing Record 20 of Set 5 | raudeberg
# Processing Record 21 of Set 5 | corbelia
# Processing Record 22 of Set 5 | vila velha
# Processing Record 23 of Set 5 | ulladulla
# Processing Record 24 of Set 5 | beringovskiy
# Processing Record 25 of Set 5 | araouane
# Processing Record 26 of Set 5 | pemba
# Processing Record 27 of Set 5 | isangel
# Processing Record 28 of Set 5 | jiroft
# City not found. Skipping...
# Processing Record 29 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 30 of Set 5 | bara
# Processing Record 31 of Set 5 | honghu
# Processing Record 32 of Set 5 | inhambane
# Processing Record 33 of Set 5 | aberdeen
# Processing Record 34 of Set 5 | mandiana
# Processing Record 35 of Set 5 | mikhaylovka
# Processing Record 36 of Set 5 | marabba
# Processing Record 37 of Set 5 | benjamin constant
# Processing Record 38 of Set 5 | longyearbyen
# Processing Record 39 of Set 5 | hami
# Processing Record 40 of Set 5 | sembe
# Processing Record 41 of Set 5 | saldanha
# Processing Record 42 of Set 5 | mesyagutovo
# Processing Record 43 of Set 5 | bobo dioulasso
# Processing Record 44 of Set 5 | valle de allende
# Processing Record 45 of Set 5 | kuryk
# Processing Record 46 of Set 5 | hithadhoo
# Processing Record 47 of Set 5 | dingle
# Processing Record 48 of Set 5 | arraial do cabo
# Processing Record 49 of Set 5 | milkovo
# Processing Record 50 of Set 5 | fortuna
# Processing Record 1 of Set 6 | shimoni
# Processing Record 2 of Set 6 | pevek
# Processing Record 3 of Set 6 | corrales
# Processing Record 4 of Set 6 | grindavik
# Processing Record 5 of Set 6 | bermejo
# Processing Record 6 of Set 6 | coihaique
# Processing Record 7 of Set 6 | ishigaki
# Processing Record 8 of Set 6 | bindi
# Processing Record 9 of Set 6 | yanam
# Processing Record 10 of Set 6 | sinnamary
# Processing Record 11 of Set 6 | broome
# Processing Record 12 of Set 6 | vilhena
# Processing Record 13 of Set 6 | plaridel
# Processing Record 14 of Set 6 | methoni
# Processing Record 15 of Set 6 | andenes
# Processing Record 16 of Set 6 | turtas
# Processing Record 17 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 6 | urubicha
# Processing Record 19 of Set 6 | rocha
# Processing Record 20 of Set 6 | nyurba
# Processing Record 21 of Set 6 | lompoc
# Processing Record 22 of Set 6 | dinard
# Processing Record 23 of Set 6 | pangkalanbuun
# Processing Record 24 of Set 6 | georgetown
# Processing Record 25 of Set 6 | coruripe
# Processing Record 26 of Set 6 | laguna
# Processing Record 27 of Set 6 | fort-shevchenko
# Processing Record 28 of Set 6 | kaeo
# Processing Record 29 of Set 6 | geraldton
# Processing Record 30 of Set 6 | boundiali
# Processing Record 31 of Set 6 | port arthur
# Processing Record 32 of Set 6 | port-gentil
# Processing Record 33 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 6 | ust-nera
# Processing Record 35 of Set 6 | egvekinot
# Processing Record 36 of Set 6 | esperance
# Processing Record 37 of Set 6 | rafai
# Processing Record 38 of Set 6 | matamoros
# Processing Record 39 of Set 6 | saint-joseph
# Processing Record 40 of Set 6 | moerai
# Processing Record 41 of Set 6 | wajir
# Processing Record 42 of Set 6 | vostok
# Processing Record 43 of Set 6 | sobolevo
# Processing Record 44 of Set 6 | terrace bay
# Processing Record 45 of Set 6 | daru
# Processing Record 46 of Set 6 | taltal
# Processing Record 47 of Set 6 | saskylakh
# Processing Record 48 of Set 6 | manbij
# Processing Record 49 of Set 6 | lazurne
# Processing Record 50 of Set 6 | pitimbu
# Processing Record 1 of Set 7 | cascais
# Processing Record 2 of Set 7 | le pradet
# Processing Record 3 of Set 7 | trairi
# Processing Record 4 of Set 7 | edd
# Processing Record 5 of Set 7 | johnson city
# Processing Record 6 of Set 7 | pasni
# Processing Record 7 of Set 7 | salo
# Processing Record 8 of Set 7 | nizhniy kuranakh
# Processing Record 9 of Set 7 | demba
# Processing Record 10 of Set 7 | burica
# City not found. Skipping...
# Processing Record 11 of Set 7 | tabou
# Processing Record 12 of Set 7 | charlestown
# Processing Record 13 of Set 7 | baft
# Processing Record 14 of Set 7 | merauke
# Processing Record 15 of Set 7 | lavrentiya
# Processing Record 16 of Set 7 | cururupu
# Processing Record 17 of Set 7 | cochrane
# Processing Record 18 of Set 7 | kushiro
# Processing Record 19 of Set 7 | lahaina
# Processing Record 20 of Set 7 | cap-chat
# Processing Record 21 of Set 7 | alofi
# Processing Record 22 of Set 7 | leningradskiy
# Processing Record 23 of Set 7 | san jose de guanipa
# Processing Record 24 of Set 7 | tiksi
# Processing Record 25 of Set 7 | benicarlo
# Processing Record 26 of Set 7 | clyde river
# Processing Record 27 of Set 7 | chapais
# Processing Record 28 of Set 7 | san rafael del sur
# Processing Record 29 of Set 7 | planaltina
# Processing Record 30 of Set 7 | vyartsilya
# Processing Record 31 of Set 7 | kosonsoy
# Processing Record 32 of Set 7 | nyazepetrovsk
# Processing Record 33 of Set 7 | jumla
# Processing Record 34 of Set 7 | shizunai
# Processing Record 35 of Set 7 | mount gambier
# Processing Record 36 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 37 of Set 7 | chara
# Processing Record 38 of Set 7 | kampot
# Processing Record 39 of Set 7 | oparino
# Processing Record 40 of Set 7 | poum
# Processing Record 41 of Set 7 | manggar
# Processing Record 42 of Set 7 | kirakira
# Processing Record 43 of Set 7 | avera
# Processing Record 44 of Set 7 | airai
# Processing Record 45 of Set 7 | namibe
# Processing Record 46 of Set 7 | general roca
# Processing Record 47 of Set 7 | valle de santiago
# Processing Record 48 of Set 7 | paamiut
# Processing Record 49 of Set 7 | lahad datu
# Processing Record 50 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 1 of Set 8 | stamsund
# City not found. Skipping...
# Processing Record 2 of Set 8 | great yarmouth
# Processing Record 3 of Set 8 | shenzhen
# Processing Record 4 of Set 8 | krasnoshchekovo
# Processing Record 5 of Set 8 | baghdad
# Processing Record 6 of Set 8 | porto santo
# Processing Record 7 of Set 8 | victoria
# Processing Record 8 of Set 8 | quatre cocos
# Processing Record 9 of Set 8 | antofagasta
# Processing Record 10 of Set 8 | san patricio
# Processing Record 11 of Set 8 | pedernales
# Processing Record 12 of Set 8 | aklavik
# Processing Record 13 of Set 8 | yar-sale
# Processing Record 14 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 8 | stromness
# Processing Record 16 of Set 8 | koyelga
# Processing Record 17 of Set 8 | calbuco
# Processing Record 18 of Set 8 | bajil
# Processing Record 19 of Set 8 | dubbo
# Processing Record 20 of Set 8 | hetauda
# Processing Record 21 of Set 8 | grand gaube
# Processing Record 22 of Set 8 | puerto ayacucho
# Processing Record 23 of Set 8 | bozoum
# Processing Record 24 of Set 8 | yurya
# City not found. Skipping...
# Processing Record 25 of Set 8 | kaoma
# Processing Record 26 of Set 8 | sambava
# Processing Record 27 of Set 8 | pangnirtung
# Processing Record 28 of Set 8 | omboue
# Processing Record 29 of Set 8 | tromso
# Processing Record 30 of Set 8 | yenagoa
# Processing Record 31 of Set 8 | trincomalee
# Processing Record 32 of Set 8 | saint anthony
# Processing Record 33 of Set 8 | dawei
# Processing Record 34 of Set 8 | pandan
# Processing Record 35 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 8 | hualmay
# Processing Record 37 of Set 8 | atambua
# Processing Record 38 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 8 | hervey bay
# Processing Record 40 of Set 8 | luganville
# Processing Record 41 of Set 8 | port lincoln
# Processing Record 42 of Set 8 | krasnyy kholm
# Processing Record 43 of Set 8 | zhigansk
# Processing Record 44 of Set 8 | balikpapan
# Processing Record 45 of Set 8 | camacha
# Processing Record 46 of Set 8 | port hedland
# Processing Record 47 of Set 8 | nybro
# Processing Record 48 of Set 8 | sibay
# Processing Record 49 of Set 8 | antsohihy
# Processing Record 50 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 1 of Set 9 | abomsa
# Processing Record 2 of Set 9 | kindu
# Processing Record 3 of Set 9 | wasilla
# Processing Record 4 of Set 9 | barranca
# Processing Record 5 of Set 9 | darab
# Processing Record 6 of Set 9 | narsaq
# Processing Record 7 of Set 9 | santa marinella
# Processing Record 8 of Set 9 | lata
# Processing Record 9 of Set 9 | kuusamo
# Processing Record 10 of Set 9 | mentok
# City not found. Skipping...
# Processing Record 11 of Set 9 | adre
# Processing Record 12 of Set 9 | altagracia de orituco
# Processing Record 13 of Set 9 | broken hill
# Processing Record 14 of Set 9 | rongcheng
# Processing Record 15 of Set 9 | krasnoselkup
# Processing Record 16 of Set 9 | nago
# Processing Record 17 of Set 9 | bressuire
# Processing Record 18 of Set 9 | kaffrine
# Processing Record 19 of Set 9 | youhao
# Processing Record 20 of Set 9 | praia da vitoria
# Processing Record 21 of Set 9 | lima
# Processing Record 22 of Set 9 | viransehir
# Processing Record 23 of Set 9 | salalah
# Processing Record 24 of Set 9 | bowen
# Processing Record 25 of Set 9 | inongo
# Processing Record 26 of Set 9 | luancheng
# Processing Record 27 of Set 9 | coquimbo
# Processing Record 28 of Set 9 | kununurra
# Processing Record 29 of Set 9 | kiyasovo
# Processing Record 30 of Set 9 | koumac
# Processing Record 31 of Set 9 | potosi
# Processing Record 32 of Set 9 | lianran
# Processing Record 33 of Set 9 | vanavara
# Processing Record 34 of Set 9 | tautira
# Processing Record 35 of Set 9 | mitsamiouli
# Processing Record 36 of Set 9 | changji
# Processing Record 37 of Set 9 | mersing
# Processing Record 38 of Set 9 | ceres
# Processing Record 39 of Set 9 | batesville
# Processing Record 40 of Set 9 | bairiki
# Processing Record 41 of Set 9 | sattahip
# Processing Record 42 of Set 9 | kyzyl-suu
# Processing Record 43 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 44 of Set 9 | romilly-sur-seine
# Processing Record 45 of Set 9 | duobao
# Processing Record 46 of Set 9 | mackay
# Processing Record 47 of Set 9 | mehamn
# Processing Record 48 of Set 9 | cesvaine
# Processing Record 49 of Set 9 | itoman
# Processing Record 50 of Set 9 | kontagora
# Processing Record 1 of Set 10 | sorkjosen
# Processing Record 2 of Set 10 | seoul
# Processing Record 3 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 4 of Set 10 | brora
# Processing Record 5 of Set 10 | kushima
# Processing Record 6 of Set 10 | lhokseumawe
# Processing Record 7 of Set 10 | rosetta
# Processing Record 8 of Set 10 | shubarkuduk
# Processing Record 9 of Set 10 | harper
# Processing Record 10 of Set 10 | pyaozerskiy
# Processing Record 11 of Set 10 | port macquarie
# Processing Record 12 of Set 10 | cheshunt
# Processing Record 13 of Set 10 | sao francisco
# Processing Record 14 of Set 10 | moosomin
# Processing Record 15 of Set 10 | baringo
# Processing Record 16 of Set 10 | lasa
# Processing Record 17 of Set 10 | qiongshan
# Processing Record 18 of Set 10 | jiaozuo
# Processing Record 19 of Set 10 | launceston
# Processing Record 20 of Set 10 | ahipara
# Processing Record 21 of Set 10 | shibata
# Processing Record 22 of Set 10 | khorixas
# Processing Record 23 of Set 10 | mayumba
# Processing Record 24 of Set 10 | sabla
# Processing Record 25 of Set 10 | campos gerais
# Processing Record 26 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 27 of Set 10 | cordoba
# Processing Record 28 of Set 10 | opuwo
# Processing Record 29 of Set 10 | le port
# Processing Record 30 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 10 | lodja
# Processing Record 32 of Set 10 | nemuro
# Processing Record 33 of Set 10 | lucea
# Processing Record 34 of Set 10 | solwezi
# Processing Record 35 of Set 10 | kalispell
# Processing Record 36 of Set 10 | xai-xai
# Processing Record 37 of Set 10 | tokmak
# Processing Record 38 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 39 of Set 10 | sicamous
# Processing Record 40 of Set 10 | severobaykalsk
# Processing Record 41 of Set 10 | tuatapere
# Processing Record 42 of Set 10 | murray bridge
# Processing Record 43 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 44 of Set 10 | ibra
# Processing Record 45 of Set 10 | berlevag
# Processing Record 46 of Set 10 | orocue
# Processing Record 47 of Set 10 | melito di porto salvo
# Processing Record 48 of Set 10 | sulecin
# Processing Record 49 of Set 10 | kungurtug
# Processing Record 50 of Set 10 | vysokogornyy
# Processing Record 1 of Set 11 | port hardy
# Processing Record 2 of Set 11 | banda aceh
# Processing Record 3 of Set 11 | munster
# Processing Record 4 of Set 11 | davila
# Processing Record 5 of Set 11 | ikwiriri
# Processing Record 6 of Set 11 | itarema
# Processing Record 7 of Set 11 | harnosand
# Processing Record 8 of Set 11 | collie
# Processing Record 9 of Set 11 | bad segeberg
# Processing Record 10 of Set 11 | aksarayskiy
# Processing Record 11 of Set 11 | barillas
# Processing Record 12 of Set 11 | kuremaa
# Processing Record 13 of Set 11 | oga
# Processing Record 14 of Set 11 | ixtapa
# Processing Record 15 of Set 11 | los alamos
# Processing Record 16 of Set 11 | lagoa
# Processing Record 17 of Set 11 | bridgetown
# Processing Record 18 of Set 11 | pointe michel
# Processing Record 19 of Set 11 | muisne
# Processing Record 20 of Set 11 | college
# Processing Record 21 of Set 11 | louis trichardt
# Processing Record 22 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 11 | tempio pausania
# Processing Record 24 of Set 11 | gushikawa
# Processing Record 25 of Set 11 | santa cruz
# Processing Record 26 of Set 11 | ponta delgada
# Processing Record 27 of Set 11 | puerto madryn
# Processing Record 28 of Set 11 | gao
# Processing Record 29 of Set 11 | chauk
# Processing Record 30 of Set 11 | jacksonville
# Processing Record 31 of Set 11 | korla
# Processing Record 32 of Set 11 | laishevo
# Processing Record 33 of Set 11 | te anau
# Processing Record 34 of Set 11 | tokonou
# Processing Record 35 of Set 11 | jinchang
# Processing Record 36 of Set 11 | cloquet
# Processing Record 37 of Set 11 | sur
# Processing Record 38 of Set 11 | arenapolis
# Processing Record 39 of Set 11 | athabasca
# Processing Record 40 of Set 11 | sovetskiy
# Processing Record 41 of Set 11 | osypenko
# Processing Record 42 of Set 11 | buraydah
# Processing Record 43 of Set 11 | itaueira
# Processing Record 44 of Set 11 | tateyama
# Processing Record 45 of Set 11 | angoche
# Processing Record 46 of Set 11 | hailar
# Processing Record 47 of Set 11 | bongandanga
# Processing Record 48 of Set 11 | tshikapa
# Processing Record 49 of Set 11 | iberia
# Processing Record 50 of Set 11 | portland
# Processing Record 1 of Set 12 | nabire
# Processing Record 2 of Set 12 | rio gallegos
# Processing Record 3 of Set 12 | vila franca do campo
# Processing Record 4 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 12 | qaqortoq
# Processing Record 6 of Set 12 | iwanai
# Processing Record 7 of Set 12 | aginskoye
# Processing Record 8 of Set 12 | haines junction
# Processing Record 9 of Set 12 | kasongo-lunda
# Processing Record 10 of Set 12 | norden
# Processing Record 11 of Set 12 | kiama
# Processing Record 12 of Set 12 | acarau
# Processing Record 13 of Set 12 | kondinskoye
# Processing Record 14 of Set 12 | carutapera
# Processing Record 15 of Set 12 | kaili
# Processing Record 16 of Set 12 | kodinar
# Processing Record 17 of Set 12 | plerin
# Processing Record 18 of Set 12 | necochea
# Processing Record 19 of Set 12 | kharitonovo
# Processing Record 20 of Set 12 | kilindoni
# Processing Record 21 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 22 of Set 12 | gunjur
# Processing Record 23 of Set 12 | tual
# Processing Record 24 of Set 12 | pajapan
# Processing Record 25 of Set 12 | saquena
# Processing Record 26 of Set 12 | ostrovnoy
# Processing Record 27 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 28 of Set 12 | bad windsheim
# Processing Record 29 of Set 12 | svetlogorsk
# Processing Record 30 of Set 12 | samoylovka
# Processing Record 31 of Set 12 | lieksa
# Processing Record 32 of Set 12 | maceio
# Processing Record 33 of Set 12 | rochegda
# Processing Record 34 of Set 12 | kholodnyy
# Processing Record 35 of Set 12 | sept-iles
# Processing Record 36 of Set 12 | roi et
# Processing Record 37 of Set 12 | tingi
# Processing Record 38 of Set 12 | caravelas
# Processing Record 39 of Set 12 | rudnyy
# Processing Record 40 of Set 12 | ostrow mazowiecka
# Processing Record 41 of Set 12 | shchuchye
# City not found. Skipping...
# Processing Record 42 of Set 12 | xinyu
# Processing Record 43 of Set 12 | aykhal
# Processing Record 44 of Set 12 | nazarovo
# Processing Record 45 of Set 12 | axim
# Processing Record 46 of Set 12 | nikolsk
# Processing Record 47 of Set 12 | burley
# Processing Record 48 of Set 12 | zanatepec
# City not found. Skipping...
# Processing Record 49 of Set 12 | tripoli
# Processing Record 50 of Set 12 | murgab
# Processing Record 1 of Set 13 | yucca valley
# Processing Record 2 of Set 13 | nalut
# Processing Record 3 of Set 13 | port blair
# Processing Record 4 of Set 13 | nuevitas
# Processing Record 5 of Set 13 | augusto correa
# Processing Record 6 of Set 13 | sudak
# Processing Record 7 of Set 13 | aksha
# Processing Record 8 of Set 13 | dalby
# Processing Record 9 of Set 13 | batagay
# Processing Record 10 of Set 13 | coahuayana
# Processing Record 11 of Set 13 | mitchell
# Processing Record 12 of Set 13 | pont-saint-esprit
# Processing Record 13 of Set 13 | havoysund
# Processing Record 14 of Set 13 | sorland
# Processing Record 15 of Set 13 | sabang
# Processing Record 16 of Set 13 | tucurui
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
new_order=['City','Country','Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
       'Wind Speed',  'Current Description']
city_data_df=city_data_df[new_order]
city_data_df
# Out:
#                   City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0            Abu Dhabi      AE  24.47   54.37     95.00        71          98
# 1               Lerici      IT  44.08    9.91     78.01        59           0
# 2               Castro      BR -24.79  -50.01     41.47        90          99
# 3             Woodward      US  36.43  -99.39     86.00        35          40
# 4              Tuy Hoa      VN  13.08  109.30     76.03        84          13
# ..                 ...     ...    ...     ...       ...       ...         ...
# 563  Pont-Saint-Esprit      FR  44.25    4.65     80.60        57           0
# 564          Havoysund      NO  71.00   24.66     59.00        82          75
# 565            Sorland      NO  67.67   12.69     55.40        93          40
# 566             Sabang      ID   5.89   95.32     83.03        70          72
# 567            Tucurui      BR  -3.77  -49.67     89.13        38          54
#
#      Wind Speed Current Description
# 0          4.70     overcast clouds
# 1          1.99           clear sky
# 2          5.23     overcast clouds
# 3         11.41    scattered clouds
# 4          6.02          few clouds
# ..          ...                 ...
# 563        6.93           clear sky
# 564        3.36       broken clouds
# 565        4.70    scattered clouds
# 566        4.74       broken clouds
# 567        1.77       broken clouds
#
# [568 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "../weather_database/weatherpy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
